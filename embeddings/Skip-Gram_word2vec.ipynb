# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:28, 1.09MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import math, random

t = 1e-5
counter = Counter(int_words)
freq = {integer: count / (0.0 + len(int_words)) for integer, count in counter.items()}
p_w = {integer: 1 - math.sqrt(t / freq[integer]) for integer in counter}
train_words = [integer for integer in int_words if random.random() > p_w[integer]]
print(len(int_words), len(train_words))
# Out:
# 16680599 4627346

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random, math

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = round(random.random() * (window_size - 1) + 1)
    # limit to prevent out of bound list index
    if R > idx:
        R = idx
    return words[idx-R:idx+R+1]

w = ["a", "b", "c", "d", "e", "c", "g", "h", "i"]
print(get_target(w, 4, 5))
# Out:
# ['a', 'b', 'c', 'd', 'e', 'c', 'g', 'h', 'i']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None))
    labels = tf.placeholder(tf.int32, shape=(None, 1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(shape=(n_vocab))) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b,
                                      labels=labels, inputs=embed, num_sampled=n_sampled,
                                      num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5960 0.3021 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.4707 0.3039 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3187 0.3106 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3485 0.3138 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2312 0.3106 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2036 0.3069 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2166 0.3116 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1486 0.3040 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1114 0.3074 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.0593 0.3031 sec/batch
# Nearest to called: postponed, deliver, vigilance, winterfell, navigator, noblemen, talons, manley,
# Nearest to when: evangelica, historiography, fandango, kuomintang, nottinghamshire, orchestral, pediatrician, institute,
# Nearest to history: calorimeter, peril, zoology, altona, explore, prehispanic, boundaries, bacteriophage,
# Nearest to such: atheneum, riffing, judgment, rotor, recant, odr, choo, belied,
# Nearest to two: semipalatinsk, looney, dial, multiplayer, smashes, jab, pontifical, fetched,
# Nearest to united: likened, ost, title, kinship, leguminous, cavern, phillips, omniscience,
# Nearest to zero: malaysian, aquifer, analysis, realism, userbase, innovated, pipeline, twickenham,
# Nearest to however: gymnastic, mayor, lipton, ln, danielle, octaves, counterintuitive, pdl,
# Nearest to account: stands, cellular, transvaal, stromata, prestwich, analog, mechanosynthesis, converters,
# Nearest to police: denigrating, landfill, geyser, divina, tivoli, mejia, frantz, sml,
# Nearest to older: guido, chur, eponyms, minuet, sociocultural, disperse, xis, revolving,
# Nearest to professional: navigated, thoughts, baldrick, fleet, battersea, frameworks, mechagodzilla, roadblocks,
# Nearest to construction: techs, homeopathic, rossum, buckingham, pickled, corpus, breasted, sniffing,
# Nearest to units: serviced, castello, plunges, chats, forties, adin, nativist, rattle,
# Nearest to experience: eustace, dulcian, peress, galego, sahib, nuevo, algonquian, chaotic,
# Nearest to test: epicycle, retinal, seals, checked, pidgin, kylix, resort, cayuga,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.0615 0.3038 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0200 0.3329 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.9775 0.3269 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.8685 0.3238 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8080 0.3214 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8382 0.3218 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.7763 0.3171 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7671 0.3197 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6804 0.3205 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.6755 0.3154 sec/batch
# Nearest to called: postponed, vigilance, deliver, navigator, noblemen, temperatures, winterfell, mmds,
# Nearest to when: kuomintang, recognition, historiography, evangelica, since, institute, fandango, tet,
# Nearest to history: calorimeter, boundaries, peril, explore, typically, zoology, repertoire, salt,
# Nearest to such: atheneum, judgment, riffing, rotor, recant, even, oba, amateur,
# Nearest to two: dial, lucy, understood, w, multiplayer, looney, out, semipalatinsk,
# Nearest to united: ost, likened, title, old, kinship, phillips, on, leguminous,
# Nearest to zero: analysis, realism, malaysian, aquifer, polish, trend, asserted, pipeline,
# Nearest to however: mayor, gymnastic, ln, octaves, era, julius, double, corrupted,
# Nearest to account: stands, cellular, prestwich, analog, transvaal, converters, stromata, users,
# Nearest to police: denigrating, landfill, tivoli, geyser, divina, sml, wolfram, mejia,
# Nearest to older: guido, chur, special, paul, smoothly, minuet, love, november,
# Nearest to professional: education, fleet, thoughts, tellingly, baldrick, weapons, battersea, frameworks,
# Nearest to construction: techs, future, rossum, homeopathic, relations, safer, statues, buckingham,
# Nearest to units: serviced, spider, overlapping, nativist, plunges, vendors, kasai, humours,
# Nearest to experience: dulcian, eustace, chaotic, peress, nuevo, hostile, contains, narrative,
# Nearest to test: epicycle, pidgin, checked, kylix, seals, cayuga, casualties, baur,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6617 0.3078 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.5986 0.3041 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.5760 0.3022 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.5632 0.3074 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.4956 0.3047 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5064 0.3028 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.4924 0.3041 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.4744 0.3107 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.4963 0.3149 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.4677 0.3036 sec/batch
# Nearest to called: postponed, deliver, vigilance, navigator, noblemen, conciliar, observing, winterfell,
# Nearest to when: evangelica, historiography, fandango, kuomintang, since, institute, banking, recognition,
# Nearest to history: calorimeter, zoology, peril, explore, repertoire, boundaries, salt, prehispanic,
# Nearest to such: atheneum, judgment, riffing, rotor, even, recant, oba, pergamon,
# Nearest to two: dial, lucy, pushed, chemist, pontifical, jab, intro, smashes,
# Nearest to united: likened, phillips, ost, title, leguminous, old, kinship, legally,
# Nearest to zero: realism, analysis, polish, malaysian, trend, isbn, uncredited, twickenham,
# Nearest to however: gymnastic, mayor, ln, era, lipton, octaves, corrupted, cathedral,
# Nearest to account: stands, cellular, analog, prestwich, transvaal, converters, users, solidarity,
# Nearest to police: tivoli, denigrating, landfill, geyser, divina, sml, wolfram, ciscs,
# Nearest to older: guido, fps, latitudes, regulatory, eponyms, chur, smoothly, revolving,
# Nearest to professional: fleet, thoughts, education, frameworks, tellingly, baldrick, battersea, navigated,
# Nearest to construction: techs, rossum, baby, relations, buckingham, pickled, corpus, homeopathic,
# Nearest to units: serviced, spider, overlapping, vendors, nativist, plunges, humours, creativity,
# Nearest to experience: eustace, dulcian, peress, hostile, narrative, chaotic, algonquian, minimum,
# Nearest to test: checked, pidgin, casualties, epicycle, incapable, pretty, baur, cayuga,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.4766 0.3079 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.4387 0.3180 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4069 0.3110 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.3672 0.3101 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4513 0.3344 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4007 0.3333 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.4079 0.3199 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4271 0.2997 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.4185 0.3007 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3461 0.3066 sec/batch
# Nearest to called: postponed, navigator, noblemen, deliver, vigilance, observing, conciliar, winterfell,
# Nearest to when: evangelica, historiography, fandango, kuomintang, nottinghamshire, tet, since, collections,
# Nearest to history: calorimeter, zoology, peril, platoon, prehispanic, boundaries, explore, repertoire,
# Nearest to such: atheneum, judgment, riffing, rotor, even, recant, pergamon, closely,
# Nearest to two: chemist, one, lucy, jab, dial, ucla, nine, intro,
# Nearest to united: likened, ost, phillips, leguminous, reciprocal, old, cavern, legally,
# Nearest to zero: polish, malaysian, isbn, analysis, four, births, realism, three,
# Nearest to however: gymnastic, octaves, lipton, ln, corrupted, era, mayor, crawling,
# Nearest to account: stands, cellular, analog, transvaal, prestwich, users, converters, trades,
# Nearest to police: denigrating, tivoli, landfill, divina, geyser, ciscs, wolfram, sml,
# Nearest to older: guido, latitudes, fps, sociocultural, regulatory, smoothly, chur, eponyms,
# Nearest to professional: thoughts, battersea, education, frameworks, navigated, tellingly, fleet, baldrick,
# Nearest to construction: techs, buckingham, rossum, pickled, breasted, homeopathic, baby, gli,
# Nearest to units: serviced, overlapping, spider, nativist, plunges, creativity, vendors, deployments,
# Nearest to experience: peress, algonquian, sahib, eustace, dulcian, hostile, galego, narrative,
# Nearest to test: pidgin, checked, incapable, cayuga, casualties, epicycle, baur, phony,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3456 0.3224 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.3315 0.3210 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.3255 0.3314 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.3022 0.3246 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3052 0.3165 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.2880 0.3168 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.3232 0.2271 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.2752 0.3110 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.2425 0.3102 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.2129 0.3107 sec/batch
# Nearest to called: postponed, deliver, noblemen, vigilance, navigator, depends, observing, mmds,
# Nearest to when: evangelica, nottinghamshire, fandango, megatokyo, historiography, kuomintang, tet, dunant,
# Nearest to history: calorimeter, zoology, prehispanic, platoon, quizzes, peril, explore, repertoire,
# Nearest to such: atheneum, judgment, rotor, riffing, even, recant, choo, pergamon,
# Nearest to two: chemist, one, lucy, zero, four, ucla, hennessy, pontifical,
# Nearest to united: likened, ost, states, leguminous, phillips, cavern, reciprocal, deputy,
# Nearest to zero: polish, four, three, two, isbn, malaysian, eight, births,
# Nearest to however: octaves, lipton, gymnastic, ln, crawling, era, danielle, outset,
# Nearest to account: stands, transvaal, analog, cellular, users, converters, prestwich, trades,
# Nearest to police: denigrating, tivoli, landfill, geyser, sml, ciscs, divina, calcutta,
# Nearest to older: guido, fps, sociocultural, regulatory, latitudes, kylix, chur, xis,
# Nearest to professional: navigated, battersea, education, frameworks, tellingly, fleet, thoughts, baldrick,
# Nearest to construction: breasted, techs, buckingham, pickled, rossum, prosecutorial, gli, aspirate,
# Nearest to units: serviced, overlapping, chemical, spider, plunges, nativist, chats, quadratic,
# Nearest to experience: peress, sahib, algonquian, eustace, galego, hostile, praises, chaotic,
# Nearest to test: pidgin, cayuga, checked, seals, incapable, kylix, achilles, epicycle,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.1735 0.3135 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.1948 0.3159 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.1824 0.3123 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.2210 0.3151 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.1861 0.3123 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.1691 0.3096 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.1406 0.3130 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.1080 0.3135 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.1301 0.3152 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.1206 0.3154 sec/batch
# Nearest to called: deliver, noblemen, postponed, vigilance, sempronius, navigator, ephraem, depends,
# Nearest to when: evangelica, megatokyo, nottinghamshire, fandango, historiography, kuomintang, raspberry, tet,
# Nearest to history: calorimeter, prehispanic, zoology, platoon, quizzes, repertoire, bacteriophage, tropics,
# Nearest to such: judgment, rotor, atheneum, riffing, even, recant, choo, iapetus,
# Nearest to two: lucy, pushed, zero, one, dial, hennessy, pontifical, smashes,
# Nearest to united: states, likened, leguminous, ost, subsidies, deputy, stamps, inductees,
# Nearest to zero: map, births, three, two, literalism, population, four, battleships,
# Nearest to however: lipton, octaves, gymnastic, hypertrophy, corrupted, danielle, crawling, era,
# Nearest to account: stands, transvaal, analog, converters, cellular, skies, trades, operationally,
# Nearest to police: denigrating, landfill, tivoli, geyser, ciscs, sml, ballots, kuwaitis,
# Nearest to older: guido, sociocultural, fps, kylix, latitudes, xis, rim, regulatory,
# Nearest to professional: education, navigated, battersea, tellingly, frameworks, montmorency, baldrick, fleet,
# Nearest to construction: breasted, techs, fuel, buckingham, prosecutorial, relations, rossum, usps,
# Nearest to units: serviced, overlapping, chemical, plunges, chats, elfin, deployments, spider,
# Nearest to experience: peress, sahib, hostile, medically, praises, eustace, algonquian, chaotic,
# Nearest to test: pidgin, kylix, checked, cayuga, incapable, seals, epicycle, achilles,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.1462 0.3164 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.1009 0.3115 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.1477 0.3111 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.0918 0.3128 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.0863 0.3124 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.1039 0.3116 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0654 0.3132 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.0754 0.3105 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.0845 0.3118 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.0312 0.3132 sec/batch
# Nearest to called: vigilance, deliver, noblemen, postponed, conciliar, talons, sempronius, navigator,
# Nearest to when: evangelica, fandango, nottinghamshire, megatokyo, typically, raspberry, kuomintang, pcl,
# Nearest to history: calorimeter, prehispanic, platoon, zoology, quizzes, repertoire, leiden, bacteriophage,
# Nearest to such: judgment, rotor, atheneum, riffing, recant, even, choo, odr,
# Nearest to two: zero, lucy, one, chemist, three, four, smashes, jab,
# Nearest to united: states, likened, leguminous, subsidies, stamps, deputy, ost, president,
# Nearest to zero: two, three, four, six, isbn, map, births, literalism,
# Nearest to however: lipton, outset, hypertrophy, octaves, gymnastic, crawling, scalability, danielle,
# Nearest to account: stands, transvaal, cellular, converters, trades, skies, analog, users,
# Nearest to police: denigrating, landfill, tivoli, geyser, villiers, ciscs, ballots, sml,
# Nearest to older: guido, sociocultural, fps, kylix, rim, xis, latitudes, households,
# Nearest to professional: education, navigated, tellingly, battersea, frameworks, montmorency, collaboration, lys,
# Nearest to construction: breasted, prosecutorial, techs, fuel, rossum, buckingham, claudio, engined,
# Nearest to units: overlapping, serviced, quantity, deployments, plunges, quadratic, chemical, chats,
# Nearest to experience: peress, hostile, praises, medically, algonquian, galego, torvalds, vague,
# Nearest to test: pidgin, checked, kylix, incapable, cayuga, propane, epicycle, phony,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.0504 0.3182 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0940 0.3128 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.0187 0.3126 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.0515 0.3133 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.0843 0.3277 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.0538 0.3174 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0918 0.3125 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.0626 0.3161 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.0388 0.3115 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.0054 0.3259 sec/batch
# Nearest to called: vigilance, talons, deliver, noblemen, postponed, sempronius, conciliar, navigator,
# Nearest to when: evangelica, nottinghamshire, fandango, raspberry, megatokyo, companionship, kuomintang, historiography,
# Nearest to history: calorimeter, prehispanic, quizzes, platoon, zoology, leiden, telekom, bacteriophage,
# Nearest to such: rotor, judgment, riffing, atheneum, recant, choo, even, belied,
# Nearest to two: zero, four, three, lucy, one, six, seven, pontifical,
# Nearest to united: states, likened, subsidies, leguminous, stamps, ost, deputy, nations,
# Nearest to zero: two, three, population, gbp, four, map, births, rate,
# Nearest to however: lipton, outset, octaves, hypertrophy, gymnastic, scalability, unknowns, danielle,
# Nearest to account: stands, skies, stromata, transvaal, invoked, phenomenalism, cellular, yves,
# Nearest to police: denigrating, tivoli, landfill, ciscs, villiers, kuwaitis, whitehall, ballots,
# Nearest to older: guido, sociocultural, kylix, fps, rim, xis, kaiserreich, households,
# Nearest to professional: education, navigated, montmorency, tellingly, battersea, frameworks, collaboration, reconstructions,
# Nearest to construction: breasted, fuel, prosecutorial, techs, claudio, validating, hydropower, engined,
# Nearest to units: serviced, overlapping, deployments, chats, quantity, elfin, approaches, absorbs,
# Nearest to experience: peress, praises, hostile, galego, medically, vague, sahib, algonquian,
# Nearest to test: checked, pidgin, propane, kylix, incapable, cayuga, epicycle, numeration,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.0354 0.3182 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9761 0.3192 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0746 0.3196 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0802 0.3170 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.0423 0.3146 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.9734 0.3174 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.9736 0.3174 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.0350 0.3151 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.9110 0.3163 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 3.9786 0.3185 sec/batch
# Nearest to called: vigilance, talons, noblemen, conciliar, deliver, sempronius, ephraem, navigator,
# Nearest to when: evangelica, nottinghamshire, fandango, raspberry, tet, companionship, megatokyo, shallower,
# Nearest to history: calorimeter, prehispanic, quizzes, zoology, leiden, historical, platoon, sesotho,
# Nearest to such: rotor, judgment, atheneum, riffing, recant, choo, even, odr,
# Nearest to two: zero, four, one, three, chemist, est, seven, six,
# Nearest to united: states, likened, subsidies, leguminous, stamps, ost, nauru, plying,
# Nearest to zero: two, births, three, four, population, rate, est, gbp,
# Nearest to however: lipton, hypertrophy, outset, octaves, scalability, gymnastic, vacancies, nynorsk,
# Nearest to account: stands, stromata, velde, phenomenalism, skies, yves, invoked, transvaal,
# Nearest to police: landfill, tivoli, denigrating, ciscs, villiers, whitehall, calcutta, kuwaitis,
# Nearest to older: guido, kylix, fps, sociocultural, rim, households, nga, kaiserreich,
# Nearest to professional: education, montmorency, navigated, tellingly, collaboration, battersea, lys, reconstructions,
# Nearest to construction: breasted, prosecutorial, fuel, techs, engined, hydropower, breakup, validating,
# Nearest to units: serviced, deployments, overlapping, quantity, plunges, chats, unit, approaches,
# Nearest to experience: peress, medically, praises, hostile, galego, sahib, vague, wants,
# Nearest to test: kylix, checked, pidgin, cayuga, incapable, propane, phony, epicycle,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.0035 0.3444 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 3.9663 0.3355 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.0248 0.1609 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9549 0.3537 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.9082 0.3451 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.9275 0.3355 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.8932 0.3180 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.9028 0.3151 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.9007 0.3073 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.8334 0.3010 sec/batch
# Nearest to called: talons, vigilance, noblemen, sempronius, deliver, ephraem, conciliar, beads,
# Nearest to when: evangelica, nottinghamshire, fandango, raspberry, pcl, tet, companionship, dunant,
# Nearest to history: prehispanic, calorimeter, quizzes, historical, zoology, platoon, leiden, sesotho,
# Nearest to such: rotor, judgment, atheneum, riffing, recant, choo, odr, amateur,
# Nearest to two: zero, three, four, est, pontifical, total, six, november,
# Nearest to united: states, subsidies, stamps, leguminous, likened, nauru, nations, ost,
# Nearest to zero: two, births, three, rate, population, est, four, gbp,
# Nearest to however: lipton, scalability, outset, hypertrophy, octaves, gymnastic, nynorsk, crawling,
# Nearest to account: stromata, phenomenalism, yves, velde, stands, invoked, skies, transvaal,
# Nearest to police: denigrating, tivoli, landfill, whitehall, ciscs, protesting, ballots, grad,
# Nearest to older: guido, kylix, fps, households, rim, sociocultural, kaiserreich, nga,
# Nearest to professional: education, montmorency, navigated, collaboration, tellingly, battersea, reconstructions, lys,
# Nearest to construction: fuel, engined, transport, breasted, prosecutorial, techs, hydropower, breakup,
# Nearest to units: serviced, deployments, overlapping, unit, supersymmetry, quantity, elfin, plunges,
# Nearest to experience: peress, medically, praises, vague, hostile, galego, sahib, chaotic,
# Nearest to test: kylix, cayuga, checked, seals, pidgin, propane, stroessner, ischemia,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.9296 0.3028 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.9180 0.3008 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.8973 0.2985 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.8080 0.3003 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.8233 0.3018 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.8672 0.2990 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.8330 0.2984 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8847 0.3261 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.8485 0.3030 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.8355 0.3017 sec/batch
# Nearest to called: vigilance, talons, noblemen, ephraem, sempronius, deliver, beads, conciliar,
# Nearest to when: evangelica, nottinghamshire, raspberry, fandango, pcl, tet, companionship, shallower,
# Nearest to history: prehispanic, calorimeter, quizzes, historical, hamer, zoology, platoon, sesotho,
# Nearest to such: rotor, judgment, atheneum, riffing, choo, odr, recant, hibernate,
# Nearest to two: zero, three, four, pontifical, total, est, november, nashwaak,
# Nearest to united: states, subsidies, leguminous, likened, stamps, reiterated, indeterminate, enacted,
# Nearest to zero: births, two, rate, three, population, four, ratio, est,
# Nearest to however: lipton, scalability, hypertrophy, outset, gymnastic, octaves, vacancies, attacking,
# Nearest to account: phenomenalism, stromata, velde, yves, undersea, invoked, skies, abolitionism,
# Nearest to police: denigrating, landfill, tivoli, whitehall, protesting, masc, ciscs, grad,
# Nearest to older: guido, households, kylix, families, rim, median, sociocultural, kaiserreich,
# Nearest to professional: education, montmorency, navigated, collaboration, tellingly, battersea, lys, frameworks,
# Nearest to construction: breasted, fuel, transport, engined, hydropower, prosecutorial, usps, claudio,
# Nearest to units: serviced, deployments, unit, absorbs, pence, quantity, metre, elfin,
# Nearest to experience: vague, peress, medically, praises, hostile, chaotic, sahib, galego,
# Nearest to test: kylix, cayuga, propane, ischemia, pidgin, checked, stroessner, incapable,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.8236 0.3042 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.8947 0.3005 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.8476 0.3017 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.8292 0.2997 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8494 0.2993 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.8638 0.3002 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8696 0.3077 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.8236 0.3088 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.8240 0.2910 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8220 0.2902 sec/batch
# Nearest to called: vigilance, talons, noblemen, sempronius, ephraem, deliver, beads, conciliar,
# Nearest to when: evangelica, fandango, nottinghamshire, raspberry, pcl, typically, tet, companionship,
# Nearest to history: prehispanic, calorimeter, quizzes, historical, zoology, hamer, leiden, sesotho,
# Nearest to such: rotor, judgment, riffing, atheneum, choo, hibernate, odr, recant,
# Nearest to two: zero, three, four, est, one, november, pontifical, six,
# Nearest to united: states, subsidies, stamps, leguminous, likened, reiterated, indeterminate, initiative,
# Nearest to zero: rate, two, births, population, three, gbp, est, four,
# Nearest to however: lipton, attacking, scalability, hypertrophy, outset, nynorsk, elastic, gymnastic,
# Nearest to account: phenomenalism, stromata, estimates, yves, velde, cellular, undersea, operationally,
# Nearest to police: denigrating, landfill, tivoli, whitehall, grad, protesting, ciscs, ballots,
# Nearest to older: guido, kylix, families, rim, households, sociocultural, kaiserreich, versus,
# Nearest to professional: education, montmorency, collaboration, navigated, tellingly, documentation, frameworks, battersea,
# Nearest to construction: breasted, fuel, engined, nanometers, zermelo, hydropower, usps, packs,
# Nearest to units: serviced, deployments, unit, pence, absorbs, quantity, metre, sidewinder,
# Nearest to experience: medically, vague, peress, hostile, praises, galego, chaotic, sahib,
# Nearest to test: kylix, propane, checked, cayuga, ischemia, pidgin, incapable, stroessner,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8750 0.2976 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8299 0.2892 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8423 0.2889 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8666 0.2906 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.8407 0.2908 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.7955 0.2898 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.8628 0.2890 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.8276 0.2889 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8726 0.2900 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.9156 0.2902 sec/batch
# Nearest to called: noblemen, talons, vigilance, sempronius, ephraem, navigator, tilly, conciliar,
# Nearest to when: evangelica, nottinghamshire, fandango, raspberry, girolamo, walid, pcl, dispersed,
# Nearest to history: prehispanic, calorimeter, historical, quizzes, hamer, innitzer, leiden, sesotho,
# Nearest to such: rotor, judgment, riffing, odr, hibernate, choo, atheneum, recant,
# Nearest to two: zero, three, four, ephraim, november, pontifical, est, grayson,
# Nearest to united: states, stamps, subsidies, reiterated, likened, ost, leguminous, enacted,
# Nearest to zero: births, rate, two, three, population, four, ratio, gbp,
# Nearest to however: lipton, outset, scalability, attacking, hypertrophy, nynorsk, unknowns, gymnastic,
# Nearest to account: phenomenalism, velde, stromata, yves, estimates, skies, cellular, expected,
# Nearest to police: denigrating, tivoli, landfill, whitehall, protesting, grad, masc, ciscs,
# Nearest to older: guido, kylix, families, kaiserreich, households, nga, rim, sociocultural,
# Nearest to professional: education, montmorency, collaboration, navigated, tellingly, frameworks, athletics, battersea,
# Nearest to construction: engined, fuel, breasted, transport, constructed, packs, zermelo, prosecutorial,
# Nearest to units: serviced, deployments, unit, pence, shehri, inquisitive, absorbs, sidewinder,
# Nearest to experience: adventure, medically, vague, northcote, sahib, peress, praises, questionnaire,
# Nearest to test: kylix, pidgin, propane, ischemia, cayuga, incapable, epicycle, stroessner,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.8873 0.2934 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.8100 0.3017 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.8231 0.3043 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.8211 0.3041 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.7292 0.2904 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.8083 0.2892 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.8341 0.2902 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.8027 0.2885 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8595 0.0550 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.8125 0.2893 sec/batch
# Nearest to called: vigilance, talons, noblemen, beads, ephraem, navigator, sempronius, winterfell,
# Nearest to when: evangelica, fandango, nottinghamshire, raspberry, pcl, typically, tet, girolamo,
# Nearest to history: prehispanic, calorimeter, historical, quizzes, zoology, hamer, leiden, relevant,
# Nearest to such: rotor, riffing, odr, choo, judgment, recant, amateur, hibernate,
# Nearest to two: zero, four, three, november, total, est, volume, hennessy,
# Nearest to united: states, stamps, reiterated, subsidies, leguminous, likened, nations, ost,
# Nearest to zero: rate, two, births, four, ratio, three, population, gbp,
# Nearest to however: lipton, outset, nynorsk, attacking, scalability, hypertrophy, gymnastic, koopa,
# Nearest to account: phenomenalism, velde, stromata, yves, estimates, expected, skies, undersea,
# Nearest to police: denigrating, tivoli, landfill, whitehall, protesting, grad, masc, isambard,
# Nearest to older: guido, households, nga, families, kylix, rim, fps, kaiserreich,
# Nearest to professional: education, montmorency, navigated, collaboration, tellingly, documentation, lys, frameworks,
# Nearest to construction: engined, breasted, fuel, constructed, packs, transport, prosecutorial, claudio,
# Nearest to units: unit, serviced, deployments, pence, metre, inquisitive, shehri, sidewinder,
# Nearest to experience: adventure, medically, northcote, sahib, chaotic, peress, hostile, praises,
# Nearest to test: kylix, cayuga, pidgin, ischemia, propane, victims, incapable, stroessner,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7769 0.2918 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7890 0.2895 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.7742 0.2893 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.7440 0.2893 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.7541 0.2896 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.6975 0.2900 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7459 0.2918 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.7494 0.2892 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.7794 0.2910 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.6897 0.2883 sec/batch
# Nearest to called: talons, vigilance, noblemen, ephraem, sempronius, beads, navigator, pirin,
# Nearest to when: evangelica, fandango, raspberry, nottinghamshire, pcl, tet, typically, westwood,
# Nearest to history: prehispanic, calorimeter, historical, quizzes, hamer, zoology, relevant, steyn,
# Nearest to such: rotor, odr, amateur, riffing, judgment, choo, primal, hibernate,
# Nearest to two: zero, three, four, november, ephraim, hennessy, staubach, pontifical,
# Nearest to united: states, stamps, subsidies, reiterated, leguminous, nations, frelimo, thalweg,
# Nearest to zero: births, rate, two, ratio, three, population, four, gbp,
# Nearest to however: lipton, scalability, outset, attacking, nynorsk, hypertrophy, gymnastic, koopa,
# Nearest to account: velde, phenomenalism, yves, stromata, skies, undersea, estimates, judea,
# Nearest to police: denigrating, tivoli, landfill, whitehall, grad, protesting, isambard, icty,
# Nearest to older: guido, households, nga, families, kylix, kaiserreich, family, rim,
# Nearest to professional: education, montmorency, navigated, tellingly, collaboration, amateur, documentation, lys,
# Nearest to construction: engined, constructed, fuel, breasted, packs, evictions, transport, claudio,
# Nearest to units: unit, serviced, deployments, pence, inquisitive, metre, sidewinder, shehri,
# Nearest to experience: medically, sahib, questionnaire, adventure, hostile, praises, vague, peress,
# Nearest to test: kylix, match, cayuga, victims, pidgin, propane, matches, stroessner,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.6918 0.2865 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.7087 0.2812 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.6683 0.2806 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.7325 0.2851 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7538 0.2796 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.7202 0.2810 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7510 0.2795 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7733 0.2805 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.7435 0.2798 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.7283 0.2799 sec/batch
# Nearest to called: vigilance, talons, ephraem, noblemen, beads, sempronius, navigator, pirin,
# Nearest to when: evangelica, fandango, typically, raspberry, pcl, nottinghamshire, tet, dispersed,
# Nearest to history: prehispanic, calorimeter, quizzes, historical, hamer, relevant, zoology, steyn,
# Nearest to such: rotor, odr, hibernate, riffing, choo, amateur, judgment, recant,
# Nearest to two: zero, three, november, four, ephraim, staubach, pontifical, est,
# Nearest to united: states, stamps, reiterated, subsidies, leguminous, legion, nations, indeterminate,
# Nearest to zero: births, rate, two, ratio, three, population, four, gbp,
# Nearest to however: lipton, scalability, outset, hypertrophy, attacking, nynorsk, koopa, crawling,
# Nearest to account: phenomenalism, stromata, yves, velde, estimates, judea, skies, expected,
# Nearest to police: denigrating, tivoli, landfill, grad, whitehall, protesting, icty, isambard,
# Nearest to older: families, guido, households, kylix, nga, kaiserreich, family, versus,
# Nearest to professional: education, montmorency, navigated, tellingly, amateur, collaboration, lys, basics,
# Nearest to construction: constructed, packs, breasted, engined, fuel, nanometers, evictions, zermelo,
# Nearest to units: unit, serviced, deployments, pence, metre, inquisitive, sidewinder, si,
# Nearest to experience: medically, adventure, hostile, sahib, questionnaire, northcote, vague, khitan,
# Nearest to test: kylix, match, propane, ischemia, cayuga, pidgin, victims, matches,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.7257 0.2832 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7429 0.2799 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.7301 0.2802 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.7062 0.2794 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.7144 0.2829 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.7245 0.2829 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7467 0.2835 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.7437 0.2827 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7538 0.2824 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7592 0.2810 sec/batch
# Nearest to called: talons, vigilance, noblemen, ephraem, sempronius, beads, navigator, pirin,
# Nearest to when: evangelica, fandango, nottinghamshire, typically, tet, raspberry, dispersed, pcl,
# Nearest to history: prehispanic, historical, calorimeter, quizzes, relevant, hamer, innitzer, leiden,
# Nearest to such: rotor, judgment, riffing, amateur, hibernate, odr, choo, recant,
# Nearest to two: zero, november, three, four, ephraim, nashwaak, staubach, est,
# Nearest to united: states, nations, subsidies, reiterated, stamps, legion, title, frelimo,
# Nearest to zero: rate, two, births, gbp, ratio, population, four, three,
# Nearest to however: lipton, outset, scalability, attacking, nynorsk, hypertrophy, koopa, fra,
# Nearest to account: phenomenalism, velde, stromata, estimates, yves, skies, judea, analog,
# Nearest to police: denigrating, tivoli, landfill, grad, whitehall, protesting, icty, proposes,
# Nearest to older: families, guido, family, kaiserreich, households, nga, kylix, rim,
# Nearest to professional: education, montmorency, navigated, amateur, tellingly, collaboration, basics, helmuth,
# Nearest to construction: constructed, packs, breasted, canoes, syntactical, hydropower, engined, nanometers,
# Nearest to units: unit, serviced, deployments, pence, inquisitive, metre, sidewinder, si,
# Nearest to experience: adventure, medically, northcote, hostile, sahib, vague, questionnaire, khitan,
# Nearest to test: propane, kylix, ischemia, pidgin, matches, incapable, stroessner, dependents,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.7384 0.2873 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.6701 0.2836 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.6925 0.2822 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7588 0.2827 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.7714 0.2829 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.8116 0.2821 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.7987 0.2817 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.7045 0.2821 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.6671 0.2827 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.7266 0.2825 sec/batch
# Nearest to called: talons, vigilance, noblemen, ephraem, beads, sempronius, navigator, conciliar,
# Nearest to when: evangelica, fandango, typically, tet, nottinghamshire, pcl, raspberry, dispersed,
# Nearest to history: prehispanic, historical, calorimeter, quizzes, hamer, zoology, steyn, relevant,
# Nearest to such: rotor, judgment, amateur, riffing, odr, hibernate, choo, primal,
# Nearest to two: zero, november, three, four, ephraim, grayson, nashwaak, staubach,
# Nearest to united: states, nations, reiterated, stamps, subsidies, title, legion, leguminous,
# Nearest to zero: rate, ratio, two, births, population, gbp, four, three,
# Nearest to however: lipton, outset, scalability, attacking, nynorsk, hypertrophy, koopa, callimachus,
# Nearest to account: phenomenalism, velde, stromata, estimates, yves, undersea, analog, kahtani,
# Nearest to police: denigrating, tivoli, landfill, grad, department, whitehall, icty, protesting,
# Nearest to older: families, households, family, nga, kaiserreich, versus, guido, females,
# Nearest to professional: education, montmorency, navigated, helmuth, tellingly, wrestler, basics, collaboration,
# Nearest to construction: constructed, packs, zermelo, evictions, hydropower, quakes, canal, spacecrafts,
# Nearest to units: unit, serviced, deployments, inquisitive, pence, metre, si, sidewinder,
# Nearest to experience: adventure, northcote, medically, sahib, peress, khitan, hostile, clocked,
# Nearest to test: propane, kylix, match, ischemia, matches, incapable, impressed, brak,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6205 0.2853 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.7245 0.2835 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.7039 0.2819 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.6763 0.2808 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7417 0.2825 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.7083 0.2591 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.6899 0.2812 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6516 0.2817 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.6691 0.2803 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.6650 0.2814 sec/batch
# Nearest to called: talons, ephraem, noblemen, vigilance, beads, sempronius, winterfell, magnoliophyta,
# Nearest to when: evangelica, fandango, nottinghamshire, pcl, tet, typically, dispersed, mobilized,
# Nearest to history: prehispanic, historical, calorimeter, quizzes, zoology, steyn, hamer, relevant,
# Nearest to such: rotor, amateur, odr, recant, judgment, primal, hibernate, erp,
# Nearest to two: zero, november, four, three, ephraim, nov, yarrow, grayson,
# Nearest to united: states, stamps, reiterated, legion, nations, subsidies, title, frelimo,
# Nearest to zero: rate, two, births, ratio, four, three, gbp, population,
# Nearest to however: lipton, scalability, outset, attacking, nynorsk, hypertrophy, gymnastic, callimachus,
# Nearest to account: phenomenalism, velde, stromata, estimates, yves, judea, undersea, skies,
# Nearest to police: denigrating, tivoli, landfill, grad, department, whitehall, icty, protesting,
# Nearest to older: families, family, households, nga, median, versus, females, kaiserreich,
# Nearest to professional: education, montmorency, navigated, tellingly, helmuth, basics, documentation, amateur,
# Nearest to construction: constructed, evictions, packs, engined, hydropower, redevelopment, spacecrafts, canal,
# Nearest to units: unit, deployments, serviced, inquisitive, metre, si, pence, sidewinder,
# Nearest to experience: medically, northcote, adventure, sahib, hostile, peress, khitan, pk,
# Nearest to test: match, propane, matches, tests, stroessner, impressed, kylix, ischemia,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.6935 0.2835 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.6300 0.2833 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.6679 0.2807 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.6915 0.2813 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.6842 0.2809 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6689 0.2809 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.5713 0.2818 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6265 0.2812 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.5714 0.2818 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6512 0.2821 sec/batch
# Nearest to called: talons, noblemen, vigilance, ephraem, beads, sempronius, conciliar, pirin,
# Nearest to when: evangelica, fandango, typically, pcl, nottinghamshire, tet, disoriented, raspberry,
# Nearest to history: prehispanic, historical, calorimeter, quizzes, hamer, zoology, steyn, eplf,
# Nearest to such: rotor, odr, primal, amateur, hibernate, recant, erp, riffing,
# Nearest to two: zero, november, three, ephraim, four, staubach, pyrotechnic, nashwaak,
# Nearest to united: states, reiterated, stamps, america, legion, nations, frelimo, title,
# Nearest to zero: rate, two, births, population, ratio, four, gbp, three,
# Nearest to however: lipton, scalability, outset, attacking, exec, hypertrophy, nynorsk, fra,
# Nearest to account: phenomenalism, velde, judea, stromata, estimates, undersea, yves, kahtani,
# Nearest to police: denigrating, landfill, grad, tivoli, icty, department, protesting, whitehall,
# Nearest to older: families, family, households, versus, median, household, husband, females,
# Nearest to professional: education, montmorency, amateur, navigated, helmuth, competition, tellingly, basics,
# Nearest to construction: constructed, engined, redevelopment, canal, fuel, zermelo, bushnell, hydropower,
# Nearest to units: unit, deployments, serviced, si, metre, inquisitive, pence, sidewinder,
# Nearest to experience: medically, adventure, northcote, sahib, hostile, pk, vague, khitan,
# Nearest to test: match, propane, tests, matches, kylix, stroessner, cayuga, impressed,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6413 0.2837 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.6564 0.2809 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.6257 0.2825 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.6630 0.2817 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.6934 0.2817 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6073 0.2802 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.6614 0.2820 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.6467 0.2813 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6627 0.2814 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6206 0.2824 sec/batch
# Nearest to called: talons, vigilance, noblemen, ephraem, sempronius, beads, conciliar, antisymmetry,
# Nearest to when: evangelica, fandango, typically, tet, nottinghamshire, pcl, raspberry, stereoisomers,
# Nearest to history: prehispanic, historical, calorimeter, quizzes, steyn, hamer, zoology, seminoles,
# Nearest to such: rotor, primal, erp, hibernate, amateur, recant, norman, riffing,
# Nearest to two: zero, november, three, ephraim, four, yarrow, staubach, grayson,
# Nearest to united: states, stamps, legion, title, reiterated, nations, america, subsidies,
# Nearest to zero: rate, two, births, ratio, gbp, population, four, three,
# Nearest to however: lipton, outset, exec, nynorsk, attacking, scalability, hypertrophy, koopa,
# Nearest to account: phenomenalism, velde, estimates, stromata, judea, yves, analog, undersea,
# Nearest to police: denigrating, tivoli, landfill, grad, department, icty, whitehall, protesting,
# Nearest to older: families, family, versus, households, household, median, husband, females,
# Nearest to professional: education, helmuth, montmorency, basics, competition, amateur, navigated, wrestler,
# Nearest to construction: constructed, zermelo, redevelopment, notions, spacecrafts, evictions, breasted, bushnell,
# Nearest to units: unit, deployments, si, serviced, metre, inquisitive, pence, sidewinder,
# Nearest to experience: medically, adventure, northcote, hostile, sahib, pk, khitan, clocked,
# Nearest to test: match, matches, tests, propane, kylix, impressed, cricket, ischemia,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6386 0.2847 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6485 0.2825 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6466 0.2824 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6560 0.2800 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.6604 0.2808 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.6571 0.2836 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6437 0.2816 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.6282 0.2835 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.6053 0.2805 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.7016 0.2811 sec/batch
# Nearest to called: talons, vigilance, noblemen, ephraem, beads, conciliar, antisymmetry, magnoliophyta,
# Nearest to when: evangelica, fandango, typically, nottinghamshire, tet, pcl, dispersed, votes,
# Nearest to history: prehispanic, historical, calorimeter, quizzes, zoology, steyn, eplf, seminoles,
# Nearest to such: rotor, erp, hibernate, amateur, recant, primal, odr, riffing,
# Nearest to two: zero, november, three, four, ephraim, grayson, yarrow, staubach,
# Nearest to united: states, nations, legion, stamps, title, frelimo, cfsp, reiterated,
# Nearest to zero: rate, two, population, births, ratio, gbp, four, three,
# Nearest to however: lipton, outset, exec, scalability, attacking, nynorsk, epsilon, cardinals,
# ...
# Nearest to construction: constructed, concrete, magee, cement, candice, textiles, pavement, pyramid,
# Nearest to units: unit, si, metre, soldiers, islander, inquisitive, nist, races,
# Nearest to experience: khitan, hispanics, brisk, engenders, pride, medford, lucasarts, sahib,
# Nearest to test: tests, match, matches, cricket, agree, kylix, impressed, klia,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.4884 0.2864 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.5072 0.2847 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.4853 0.2848 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.5035 0.2860 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.4878 0.2862 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5437 0.2856 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.5290 0.2863 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.4978 0.2840 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.5185 0.2873 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.5122 0.2872 sec/batch
# Nearest to called: talons, vigilance, ephraem, antisymmetry, dwarfs, noblemen, beads, magnoliophyta,
# Nearest to when: typically, fandango, herbivore, endothermy, disraeli, institute, tet, faithfully,
# Nearest to history: prehispanic, historical, barbarians, ucmp, calorimeter, eplf, marino, ccel,
# Nearest to such: amateur, rotor, gai, erp, hibernate, riffing, catalonia, agoraphobic,
# Nearest to two: november, ephraim, zero, yarrow, nov, oaau, three, stranglehold,
# Nearest to united: states, nations, reaffirmed, frelimo, legion, america, affleck, title,
# Nearest to zero: rate, births, ratio, population, two, isbn, squared, gbp,
# Nearest to however: correctness, exec, matchups, lipton, moldavia, identified, doraemon, scalability,
# Nearest to account: artesian, nashville, estimates, borax, phenomenalism, kahtani, numerical, drachma,
# Nearest to police: denigrating, uniformed, icty, department, incriminating, enforcement, nhs, landfill,
# Nearest to older: average, families, family, median, husband, household, households, age,
# Nearest to professional: wrestler, helmuth, amateur, stereotyped, supercup, alemanni, competition, sef,
# Nearest to construction: constructed, magee, textiles, cement, concrete, pyramid, candice, canal,
# Nearest to units: unit, si, soldiers, metre, inquisitive, islander, nist, races,
# Nearest to experience: hispanics, khitan, pride, lucasarts, medford, brisk, adventure, northcote,
# Nearest to test: tests, matches, match, cricket, agree, kylix, impressed, steady,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.5383 0.2886 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.4772 0.2875 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.4825 0.2855 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.4638 0.2834 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.5528 0.2879 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5262 0.2864 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.6313 0.2895 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5582 0.2864 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.5566 0.2836 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.4667 0.2840 sec/batch
# Nearest to called: talons, antisymmetry, ephraem, vigilance, dwarfs, beads, markkaa, initially,
# Nearest to when: typically, fandango, endothermy, institute, disraeli, herbivore, tet, onset,
# Nearest to history: prehispanic, historical, barbarians, calorimeter, ucmp, eplf, marino, ccel,
# Nearest to such: erp, amateur, rotor, gai, lhasa, hibernate, riffing, agoraphobic,
# Nearest to two: november, yarrow, ephraim, zero, oaau, nov, july, thecrimson,
# Nearest to united: states, nations, reaffirmed, affleck, signers, legion, frelimo, enacted,
# Nearest to zero: population, births, rate, ratio, two, squared, isbn, nintoku,
# Nearest to however: exec, lipton, correctness, matchups, doraemon, identified, moldavia, praetor,
# Nearest to account: artesian, nashville, estimates, numerical, borax, judea, boos, kahtani,
# Nearest to police: denigrating, department, uniformed, icty, boarding, officers, nhs, masc,
# Nearest to older: average, median, family, husband, families, household, age, versus,
# Nearest to professional: wrestler, helmuth, stereotyped, supercup, alemanni, amateur, hazzard, montmorency,
# Nearest to construction: constructed, magee, cement, concrete, notions, canal, textiles, candice,
# Nearest to units: unit, si, metre, nist, soldiers, islander, inquisitive, races,
# Nearest to experience: hispanics, khitan, medford, lucasarts, brisk, pride, gypsys, northcote,
# Nearest to test: tests, matches, match, cricket, agree, impressed, kylix, steady,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.4290 0.2876 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.5077 0.2850 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4389 0.2843 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5310 0.2859 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.4956 0.2829 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.5114 0.2843 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5447 0.1617 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.4722 0.2840 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.5098 0.2842 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.4888 0.2832 sec/batch
# Nearest to called: talons, ephraem, antisymmetry, initially, dwarfs, magnoliophyta, vigilance, beads,
# Nearest to when: typically, fandango, disraeli, institute, endothermy, faithfully, herbivore, yuma,
# Nearest to history: prehispanic, historical, barbarians, calorimeter, ucmp, guide, eplf, steyn,
# Nearest to such: amateur, lhasa, rotor, erp, gai, catalonia, hibernate, interpretations,
# Nearest to two: november, nov, yarrow, ephraim, zero, jun, oaau, july,
# Nearest to united: states, nations, affleck, reaffirmed, legion, signers, frelimo, checksum,
# Nearest to zero: births, rate, squared, population, nintoku, two, ratio, swahili,
# Nearest to however: exec, doraemon, identified, correctness, lipton, moldavia, praetor, matchups,
# Nearest to account: nashville, artesian, kahtani, boos, borax, estimates, drachma, numerical,
# Nearest to police: denigrating, uniformed, department, icty, officers, boarding, landfill, nhs,
# Nearest to older: average, husband, family, median, families, household, age, versus,
# Nearest to professional: wrestler, helmuth, stereotyped, amateur, alemanni, supercup, sutherland, hazzard,
# Nearest to construction: constructed, magee, concrete, cement, textiles, notions, candice, pyramid,
# Nearest to units: unit, si, nist, metre, redefined, inquisitive, soldiers, islander,
# Nearest to experience: khitan, hispanics, medford, lucasarts, brisk, pride, northcote, harmonize,
# Nearest to test: tests, matches, match, cricket, impressed, agree, kylix, steady,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.4639 0.2869 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.4961 0.2832 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.4599 0.2850 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.4643 0.2881 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.5018 0.2840 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.4747 0.2842 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.5234 0.2840 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4180 0.2843 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.4698 0.2834 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.4422 0.2832 sec/batch
# Nearest to called: talons, antisymmetry, ephraem, initially, subshells, vigilance, beads, dwarfs,
# Nearest to when: typically, fandango, disraeli, endothermy, herbivore, faithfully, yuma, institute,
# Nearest to history: prehispanic, historical, barbarians, ucmp, calorimeter, guide, marino, unr,
# Nearest to such: amateur, catalonia, lhasa, rotor, gai, erp, hibernate, interpretations,
# Nearest to two: november, yarrow, ephraim, nov, zero, three, oaau, jun,
# Nearest to united: states, nations, affleck, america, legion, reaffirmed, frelimo, cmu,
# Nearest to zero: births, population, swahili, rate, ratio, squared, two, isbn,
# Nearest to however: exec, correctness, identified, doraemon, lipton, matchups, praetor, equally,
# Nearest to account: artesian, nashville, borax, numerical, estimates, kahtani, drachma, boos,
# Nearest to police: denigrating, uniformed, department, icty, officers, masc, departments, incriminating,
# Nearest to older: average, husband, median, household, family, families, age, versus,
# Nearest to professional: wrestler, helmuth, amateur, stereotyped, alemanni, supercup, unusually, sutherland,
# Nearest to construction: constructed, concrete, cement, textiles, magee, candice, completed, pyramid,
# Nearest to units: unit, si, nist, metre, soldiers, redefined, inquisitive, islander,
# Nearest to experience: hispanics, khitan, lucasarts, medford, brisk, harmonize, pride, engenders,
# Nearest to test: tests, matches, match, cricket, impressed, agree, whaling, steady,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.4117 0.2860 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.4530 0.2847 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.4903 0.2854 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.4980 0.2826 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.4572 0.2863 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.5530 0.2842 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.5059 0.2854 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.4531 0.2857 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.4682 0.2848 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.4931 0.2847 sec/batch
# Nearest to called: talons, antisymmetry, initially, ephraem, dwarfs, beads, vigilance, magnoliophyta,
# Nearest to when: typically, fandango, disraeli, herbivore, endothermy, faithfully, institute, yuma,
# Nearest to history: prehispanic, historical, barbarians, guide, ucmp, unr, marino, calorimeter,
# Nearest to such: amateur, gai, rotor, erp, catalonia, hibernate, lhasa, agoraphobic,
# Nearest to two: november, yarrow, zero, ephraim, nov, oaau, jun, three,
# Nearest to united: states, nations, legion, reaffirmed, frelimo, america, signers, checksum,
# Nearest to zero: births, population, two, rate, paparizou, squared, isbn, swahili,
# Nearest to however: exec, doraemon, correctness, lipton, identified, radiator, matchups, moldavia,
# Nearest to account: nashville, artesian, estimates, borax, numerical, kahtani, phenomenalism, drachma,
# Nearest to police: denigrating, uniformed, icty, department, officers, incriminating, nhs, enforcement,
# Nearest to older: average, families, household, husband, median, family, versus, age,
# Nearest to professional: wrestler, helmuth, amateur, stereotyped, supercup, alemanni, sef, hazzard,
# Nearest to construction: constructed, concrete, cement, magee, textiles, candice, completed, pavement,
# Nearest to units: unit, si, metre, nist, soldiers, islander, inquisitive, redefined,
# Nearest to experience: hispanics, medford, khitan, lucasarts, brisk, harmonize, northcote, adventure,
# Nearest to test: tests, matches, match, cricket, impressed, agree, kylix, steady,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.5105 0.2884 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.4882 0.2853 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.4747 0.2847 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.4840 0.2859 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.5042 0.2868 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.5178 0.2857 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.4907 0.2841 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.4948 0.2826 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.4585 0.2845 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.4724 0.2848 sec/batch
# Nearest to called: talons, antisymmetry, ephraem, dwarfs, initially, magnoliophyta, beads, vigilance,
# Nearest to when: typically, fandango, disraeli, herbivore, endothermy, faithfully, yuma, institute,
# Nearest to history: prehispanic, historical, barbarians, marino, ucmp, guide, calorimeter, unr,
# Nearest to such: amateur, erp, gai, agoraphobic, hibernate, catalonia, rotor, lhasa,
# Nearest to two: november, zero, yarrow, three, four, ephraim, nov, oaau,
# Nearest to united: states, nations, reaffirmed, legion, america, enacted, frelimo, checksum,
# Nearest to zero: population, rate, births, two, isbn, ratio, squared, swahili,
# Nearest to however: exec, identified, correctness, doraemon, lipton, radiator, moldavia, matchups,
# Nearest to account: nashville, artesian, estimates, numerical, borax, kahtani, phenomenalism, drachma,
# Nearest to police: uniformed, department, denigrating, icty, officers, incriminating, departments, nhs,
# Nearest to older: average, families, family, household, avm, versus, husband, median,
# Nearest to professional: wrestler, helmuth, stereotyped, amateur, alemanni, supercup, sef, certifications,
# Nearest to construction: constructed, concrete, magee, cement, textiles, pyramid, completed, candice,
# Nearest to units: unit, si, soldiers, metre, nist, islander, inquisitive, redefined,
# Nearest to experience: hispanics, lucasarts, medford, khitan, adventure, harmonize, pride, brisk,
# Nearest to test: tests, matches, match, cricket, kylix, steady, whaling, impressed,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.5025 0.2845 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.4750 0.2837 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.5767 0.2829 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.5758 0.2842 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.5062 0.2822 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.5032 0.2846 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.4097 0.2843 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.4700 0.2845 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.3955 0.2837 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.5183 0.2839 sec/batch
# Nearest to called: talons, antisymmetry, initially, dwarfs, ephraem, magnoliophyta, beads, vigilance,
# Nearest to when: typically, fandango, disraeli, endothermy, faithfully, herbivore, institute, yuma,
# Nearest to history: prehispanic, historical, barbarians, guide, calorimeter, ucmp, marino, strengths,
# Nearest to such: amateur, gai, erp, interpretations, agoraphobic, lhasa, catalonia, hibernate,
# Nearest to two: november, zero, yarrow, ephraim, four, nov, oaau, three,
# Nearest to united: states, nations, reaffirmed, frelimo, legion, signers, america, checksum,
# Nearest to zero: births, population, rate, two, female, isbn, swahili, male,
# Nearest to however: doraemon, lipton, exec, identified, radiator, cradle, correctness, satsuma,
# Nearest to account: numerical, artesian, estimates, nashville, borax, kahtani, velde, boos,
# Nearest to police: department, uniformed, denigrating, officers, departments, icty, incriminating, nhs,
# Nearest to older: average, families, avm, family, median, household, versus, age,
# Nearest to professional: wrestler, helmuth, alemanni, stereotyped, supercup, amateur, completion, hazzard,
# Nearest to construction: constructed, magee, cement, concrete, textiles, completed, pyramid, reciprocal,
# Nearest to units: unit, si, nist, metre, soldiers, islander, inquisitive, redefined,
# Nearest to experience: hispanics, lucasarts, khitan, medford, harmonize, brisk, gypsys, pride,
# Nearest to test: tests, matches, match, cricket, whaling, steady, agree, kylix,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.4829 0.2869 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.4879 0.2842 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
